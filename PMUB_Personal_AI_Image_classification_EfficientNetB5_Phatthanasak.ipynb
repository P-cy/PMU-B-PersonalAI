# %% [markdown]
# <a href="https://colab.research.google.com/github/P-cy/PMU-B-PersonalAI/blob/main/PMUB_Personal_AI_Image_classification_EfficientNetB5_Phatthanasak.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Cats vs Dogs : Image Classification using EfficienNet

# %% [markdown]
# ## Data Description
#
# **The training archive contains 25,000 images of dogs and cats.**

# %% [markdown]
# ## Install

# %%
# !pip install efficientnet
# !pip install tensorflow==2.14.0
# !pip install pandas==1.3.5
# Out:
# Requirement already satisfied: efficientnet in /usr/local/lib/python3.10/dist-packages (1.1.1)
# Requirement already satisfied: keras-applications<=1.0.8,>=1.0.7 in /usr/local/lib/python3.10/dist-packages (from efficientnet) (1.0.8)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.10/dist-packages (from efficientnet) (0.24.0)
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.10/dist-packages (from keras-applications<=1.0.8,>=1.0.7->efficientnet) (1.26.4)
# Requirement already satisfied: h5py in /usr/local/lib/python3.10/dist-packages (from keras-applications<=1.0.8,>=1.0.7->efficientnet) (3.12.1)
# Requirement already satisfied: scipy>=1.9 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet) (1.13.1)
# Requirement already satisfied: networkx>=2.8 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet) (3.4.2)
# Requirement already satisfied: pillow>=9.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet) (11.0.0)
# Requirement already satisfied: imageio>=2.33 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet) (2.36.0)
# Requirement already satisfied: tifffile>=2022.8.12 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet) (2024.9.20)
# Requirement already satisfied: packaging>=21 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet) (24.2)
# Requirement already satisfied: lazy-loader>=0.4 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet) (0.4)
# Requirement already satisfied: tensorflow==2.14.0 in /usr/local/lib/python3.10/dist-packages (2.14.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.14.0) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.14.0) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.14.0) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.14.0) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.14.0) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.14.0) (3.12.1)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.14.0) (18.1.1)
# Requirement already satisfied: ml-dtypes==0.2.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.14.0) (0.2.0)
# Requirement already satisfied: numpy>=1.23.5 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.14.0) (1.26.4)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.14.0) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.14.0) (24.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.14.0) (4.25.5)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.14.0) (75.1.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.14.0) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.14.0) (2.5.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.14.0) (4.12.2)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.14.0) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.14.0) (0.37.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.14.0) (1.68.0)
# Requirement already satisfied: tensorboard<2.15,>=2.14 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.14.0) (2.14.1)
# Requirement already satisfied: tensorflow-estimator<2.15,>=2.14.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.14.0) (2.14.0)
# Requirement already satisfied: keras<2.15,>=2.14.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.14.0) (2.14.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow==2.14.0) (0.45.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.15,>=2.14->tensorflow==2.14.0) (2.27.0)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.15,>=2.14->tensorflow==2.14.0) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.15,>=2.14->tensorflow==2.14.0) (3.7)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.15,>=2.14->tensorflow==2.14.0) (2.32.3)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.15,>=2.14->tensorflow==2.14.0) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.15,>=2.14->tensorflow==2.14.0) (3.1.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow==2.14.0) (5.5.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow==2.14.0) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow==2.14.0) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.15,>=2.14->tensorflow==2.14.0) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.15,>=2.14->tensorflow==2.14.0) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.15,>=2.14->tensorflow==2.14.0) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.15,>=2.14->tensorflow==2.14.0) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.15,>=2.14->tensorflow==2.14.0) (2024.8.30)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.15,>=2.14->tensorflow==2.14.0) (3.0.2)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.15,>=2.14->tensorflow==2.14.0) (0.6.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.15,>=2.14->tensorflow==2.14.0) (3.2.2)
# Requirement already satisfied: pandas==1.3.5 in /usr/local/lib/python3.10/dist-packages (1.3.5)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.10/dist-packages (from pandas==1.3.5) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.10/dist-packages (from pandas==1.3.5) (2024.2)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas==1.3.5) (1.26.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7.3->pandas==1.3.5) (1.16.0)

# %% [markdown]
# ## Loading Libraries
#
# > TensorFlow

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Basic
import os
from os import makedirs
from os import listdir
from shutil import copyfile
from random import seed
from random import random
import numpy as np
import pandas as pd
from PIL import Image, ImageFile

# visuals
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.image import imread
from PIL import Image

# Scikit-learn
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report,confusion_matrix,ConfusionMatrixDisplay

# Tensorflow
import tensorflow as tf
from tensorflow.keras import callbacks
from keras.callbacks import Callback
from keras import layers
from keras import models
from tensorflow.keras import optimizers
from keras.optimizers import Adam
from efficientnet.keras import center_crop_and_resize, preprocess_input
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.14.0

# %%
dataset_url = 'https://download.microsoft.com/download/3/E/1/3E1C3F21-ECDB-4869-8368-6DEBA77B919F/kagglecatsanddogs_5340.zip'

# %% [markdown]
# ## Data Extraction

# %%
data_dir = '/content/sample_data'
# %cd '/content/sample_data'
# !pwd
# Out:
# /content/sample_data
# /content/sample_data

# %%
path_to_downloaded_file = tf.keras.utils.get_file(
    origin=dataset_url,
    extract=True,
)

# %%
path_to_downloaded_file
# Out:
# '/root/.keras/datasets/kagglecatsanddogs_5340.zip'

# %%
import zipfile

with zipfile.ZipFile(path_to_downloaded_file, 'r') as zipp:
    zipp.extractall(data_dir)

# %%
import glob

Cat_count = len(list(glob.glob(f'{data_dir}/PetImages/Cat/*.jpg')))
print('Cat: ', Cat_count)

Dog_count = len(list(glob.glob(f'{data_dir}/PetImages/Dog/*.jpg')))
print('Dog: ', Dog_count)
# Out:
# Cat:  12500
# Dog:  12500

# %% [markdown]
# ### Loading Images in a Dataframe

# %%
df_dada = pd.DataFrame(columns=['filename', 'label'])
list_dir = ["Cat", "Dog"]
for label in list_dir:
    filenames = list(glob.glob(f'{data_dir}/PetImages/{label}/*.jpg'))
    #labels = [x.split("/")[3] for x in filenames]
    data = pd.DataFrame({"filename": filenames, "label": label})
    data = data.iloc[:1250,]
    df_dada = df_dada.append(data)

print(df_dada.shape)
df_dada.head()
# Out:
# (2500, 2)
#                                        filename label
# 0   /content/sample_data/PetImages/Cat/9962.jpg   Cat
# 1   /content/sample_data/PetImages/Cat/8828.jpg   Cat
# 2  /content/sample_data/PetImages/Cat/11501.jpg   Cat
# 3   /content/sample_data/PetImages/Cat/1926.jpg   Cat
# 4   /content/sample_data/PetImages/Cat/2157.jpg   Cat

# %% [markdown]
# ## Data Exploration

# %%
plt.figure(figsize=(20,20)) # specifying the overall grid size
plt.subplots_adjust(hspace=0.4)


for i in range(10):

    plt.subplot(1,10,i+1)    # the number of images in the grid is 10*10 (100)
    filename = f'{data_dir}/PetImages/Dog/{str(i)}.jpg'
    image = imread(filename)
    plt.imshow(image)
    plt.title('Dog',fontsize=12)
    plt.axis('off')

plt.show()

# %%
plt.figure(figsize=(20,20)) # specifying the overall grid size
plt.subplots_adjust(hspace=0.4)


for i in range(10):

    plt.subplot(1,10,i+1)    # the number of images in the grid is 10*10 (100)
    filename = f'{data_dir}/PetImages/Cat/{str(i)}.jpg'
    image = imread(filename)
    plt.imshow(image)
    plt.title('Cat',fontsize=12)
    plt.axis('off')

# %% [markdown]
# ### Train Test Split

# %%
# train test split using dataframe

labels = df_dada['label']

X_train, X_temp = train_test_split(df_dada, test_size=0.2, stratify=labels, random_state = 42)

label_test_val = X_temp['label']

X_test, X_val = train_test_split(X_temp, test_size=0.5, stratify=label_test_val, random_state = 42)

print('The shape of train data',X_train.shape)
print('The shape of test data',X_test.shape)
print('The shape of validation data',X_val.shape)
# Out:
# The shape of train data (2000, 2)
# The shape of test data (250, 2)
# The shape of validation data (250, 2)

# %%
labels = ['Cat','Dog']

label1,count1 = np.unique(X_train.label,return_counts=True)
label2,count2 = np.unique(X_val.label,return_counts=True)
label3,count3 = np.unique(X_test.label,return_counts=True)

uni1 = pd.DataFrame(data=count1,index=labels,columns=['Count1'])
uni2 = pd.DataFrame(data=count2,index=labels,columns=['Count2'])
uni3 = pd.DataFrame(data=count3,index=labels,columns=['Count3'])


plt.figure(figsize=(20,6),dpi=200)
sns.set_style('darkgrid')

plt.subplot(131)
sns.barplot(data=uni1,x=uni1.index,y='Count1',palette='icefire',width=0.2).set_title('Class distribution in Training set',fontsize=15)
plt.xlabel('Labels',fontsize=12)
plt.ylabel('Count',fontsize=12)

plt.subplot(132)
sns.barplot(data=uni2,x=uni2.index,y='Count2',palette='icefire',width=0.2).set_title('Class distribution in validation set',fontsize=15)
plt.xlabel('Labels',fontsize=12)
plt.ylabel('Count',fontsize=12)


plt.subplot(133)
sns.barplot(data=uni3,x=uni3.index,y='Count3',palette='icefire',width=0.2).set_title('Class distribution in Testing set',fontsize=15)
plt.xlabel('Labels',fontsize=12)
plt.ylabel('Count',fontsize=12)

plt.show()
# Out:
# <ipython-input-18-418fb063fcee>:16: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=uni1,x=uni1.index,y='Count1',palette='icefire',width=0.2).set_title('Class distribution in Training set',fontsize=15)
# <ipython-input-18-418fb063fcee>:21: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=uni2,x=uni2.index,y='Count2',palette='icefire',width=0.2).set_title('Class distribution in validation set',fontsize=15)
# <ipython-input-18-418fb063fcee>:27: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=uni3,x=uni3.index,y='Count3',palette='icefire',width=0.2).set_title('Class distribution in Testing set',fontsize=15)

# %% [markdown]
# ### Data Preparation

# %%
# parameters
target_size = (128, 128)
batch_size = 8

# %% [markdown]
# ### Image Data Generator
#
# -  The data for will used by flow_from_dataframe.
#
# - The batch size is 8 and the image size is (128, 128).

# %%
# Creating image data generator
train_datagen = ImageDataGenerator(rescale=1./255,
                                    rotation_range = 15,
                                    horizontal_flip = True,
                                    zoom_range = 0.2,
                                    shear_range = 0.1,
                                    fill_mode = 'nearest',
                                    width_shift_range = 0.1,
                                    height_shift_range = 0.1)

test_datagen = ImageDataGenerator(rescale=1./255)

# %%
# Applying image data gernerator to train and test data

train_generator = train_datagen.flow_from_dataframe(X_train,
                                                    directory = None,
                                                    x_col= 'filename',
                                                    y_col= 'label',
                                                    batch_size = batch_size,
                                                    target_size = target_size,
                                                    class_mode='categorical',
                                                    color_mode= 'rgb'
                                                   )
val_generator = test_datagen.flow_from_dataframe(X_val,
                                                 directory = None,
                                                 x_col= 'filename',
                                                 y_col= 'label',
                                                 batch_size = batch_size,
                                                 target_size = target_size,
                                                 class_mode='categorical',
                                                 color_mode= 'rgb'
                                                )

test_generator = test_datagen.flow_from_dataframe(X_test,
                                                  directory = None,
                                                  x_col= 'filename',
                                                  y_col= 'label',
                                                  batch_size = batch_size,
                                                  target_size = target_size,
                                                  class_mode='categorical',
                                                  color_mode= 'rgb'
                                                 )
# Out:
# Found 2000 validated image filenames belonging to 2 classes.
# Found 250 validated image filenames belonging to 2 classes.
# Found 250 validated image filenames belonging to 2 classes.

# %%
#label
labels = (train_generator.class_indices)
print(labels)
# Out:
# {'Cat': 0, 'Dog': 1}

# %%
import cv2
import PIL
from PIL import Image

# %matplotlib inline
from matplotlib import pyplot as plt

w = 10
h = 10
fig = plt.figure(figsize=(12, 15))
columns = 2
rows = 4
x, y = train_generator.next()
for i in range(0, columns*rows):
    image = x[i]
    fig.add_subplot(rows, columns, i+1)
    plt.imshow(image)
plt.show()

# %% [markdown]
# ## EfficienNet Model

# %%
# loading pretrained conv base model
from efficientnet.keras import EfficientNetB5 as Net

input_shape = (128, 128, 3)
conv_base = Net(weights='imagenet', include_top=False, input_shape=input_shape)
print(f"Input Shape: {input_shape}")

# create new model with a new classification layer
x = conv_base.output
global_average_layer = layers.GlobalAveragePooling2D(name = 'head_pooling')(x)
dropout_layer = layers.Dropout(0.20,name = 'head_dropout')(global_average_layer)
prediction_layer = layers.Dense(2, activation='softmax',name = 'predict_Cat_Dog')(dropout_layer)

### FC layer
model = models.Model(inputs= conv_base.input, outputs=prediction_layer, name = 'EffNet_Cat_Dog')
# Out:
# Downloading data from https://github.com/Callidior/keras-applications/releases/download/efficientnet/efficientnet-b5_weights_tf_dim_ordering_tf_kernels_autoaugment_notop.h5
# 115515256/115515256 [==============================] - 1s 0us/step
# Input Shape: (128, 128, 3)

# %%
### Unfreeze FC layer
print('[INFO]: This is the number of trainable layers '
      'before freezing the conv base:', len(model.trainable_weights))
print('[INFO]: Freezing hidden layers...')
for layer in conv_base.layers:
    layer.trainable = False

print('[INFO]: This is the number of trainable layers '
        'after freezing the conv base:', len(model.trainable_weights))
print('-'*125)
# Out:
# [INFO]: This is the number of trainable layers before freezing the conv base: 506
# [INFO]: Freezing hidden layers...
# [INFO]: This is the number of trainable layers after freezing the conv base: 2
# -----------------------------------------------------------------------------------------------------------------------------

# %%
model.summary()
# Out:
# Model: "EffNet_Cat_Dog"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 128, 128, 3)]        0         []
#
#  stem_conv (Conv2D)          (None, 64, 64, 48)           1296      ['input_1[0][0]']
#
#  stem_bn (BatchNormalizatio  (None, 64, 64, 48)           192       ['stem_conv[0][0]']
#  n)
#
#  stem_activation (Activatio  (None, 64, 64, 48)           0         ['stem_bn[0][0]']
#  n)
#
#  block1a_dwconv (DepthwiseC  (None, 64, 64, 48)           432       ['stem_activation[0][0]']
#  onv2D)
#
#  block1a_bn (BatchNormaliza  (None, 64, 64, 48)           192       ['block1a_dwconv[0][0]']
#  tion)
#
#  block1a_activation (Activa  (None, 64, 64, 48)           0         ['block1a_bn[0][0]']
#  tion)
#
#  block1a_se_squeeze (Global  (None, 48)                   0         ['block1a_activation[0][0]']
#  AveragePooling2D)
#
#  block1a_se_reshape (Reshap  (None, 1, 1, 48)             0         ['block1a_se_squeeze[0][0]']
#  e)
#
#  block1a_se_reduce (Conv2D)  (None, 1, 1, 12)             588       ['block1a_se_reshape[0][0]']
#
#  block1a_se_expand (Conv2D)  (None, 1, 1, 48)             624       ['block1a_se_reduce[0][0]']
#
#  block1a_se_excite (Multipl  (None, 64, 64, 48)           0         ['block1a_activation[0][0]',
#  y)                                                                  'block1a_se_expand[0][0]']
#
#  block1a_project_conv (Conv  (None, 64, 64, 24)           1152      ['block1a_se_excite[0][0]']
#  2D)
#
#  block1a_project_bn (BatchN  (None, 64, 64, 24)           96        ['block1a_project_conv[0][0]']
#  ormalization)
#
#  block1b_dwconv (DepthwiseC  (None, 64, 64, 24)           216       ['block1a_project_bn[0][0]']
#  onv2D)
#
#  block1b_bn (BatchNormaliza  (None, 64, 64, 24)           96        ['block1b_dwconv[0][0]']
#  tion)
#
#  block1b_activation (Activa  (None, 64, 64, 24)           0         ['block1b_bn[0][0]']
#  tion)
#
#  block1b_se_squeeze (Global  (None, 24)                   0         ['block1b_activation[0][0]']
#  AveragePooling2D)
#
#  block1b_se_reshape (Reshap  (None, 1, 1, 24)             0         ['block1b_se_squeeze[0][0]']
#  e)
#
#  block1b_se_reduce (Conv2D)  (None, 1, 1, 6)              150       ['block1b_se_reshape[0][0]']
#
#  block1b_se_expand (Conv2D)  (None, 1, 1, 24)             168       ['block1b_se_reduce[0][0]']
#
#  block1b_se_excite (Multipl  (None, 64, 64, 24)           0         ['block1b_activation[0][0]',
#  y)                                                                  'block1b_se_expand[0][0]']
#
#  block1b_project_conv (Conv  (None, 64, 64, 24)           576       ['block1b_se_excite[0][0]']
#  2D)
#
#  block1b_project_bn (BatchN  (None, 64, 64, 24)           96        ['block1b_project_conv[0][0]']
#  ormalization)
#
#  block1b_drop (FixedDropout  (None, 64, 64, 24)           0         ['block1b_project_bn[0][0]']
#  )
#
#  block1b_add (Add)           (None, 64, 64, 24)           0         ['block1b_drop[0][0]',
#                                                                      'block1a_project_bn[0][0]']
#
#  block1c_dwconv (DepthwiseC  (None, 64, 64, 24)           216       ['block1b_add[0][0]']
#  onv2D)
#
#  block1c_bn (BatchNormaliza  (None, 64, 64, 24)           96        ['block1c_dwconv[0][0]']
#  tion)
#
#  block1c_activation (Activa  (None, 64, 64, 24)           0         ['block1c_bn[0][0]']
#  tion)
#
#  block1c_se_squeeze (Global  (None, 24)                   0         ['block1c_activation[0][0]']
#  AveragePooling2D)
#
#  block1c_se_reshape (Reshap  (None, 1, 1, 24)             0         ['block1c_se_squeeze[0][0]']
#  e)
#
#  block1c_se_reduce (Conv2D)  (None, 1, 1, 6)              150       ['block1c_se_reshape[0][0]']
#
#  block1c_se_expand (Conv2D)  (None, 1, 1, 24)             168       ['block1c_se_reduce[0][0]']
#
#  block1c_se_excite (Multipl  (None, 64, 64, 24)           0         ['block1c_activation[0][0]',
#  y)                                                                  'block1c_se_expand[0][0]']
#
#  block1c_project_conv (Conv  (None, 64, 64, 24)           576       ['block1c_se_excite[0][0]']
#  2D)
#
#  block1c_project_bn (BatchN  (None, 64, 64, 24)           96        ['block1c_project_conv[0][0]']
#  ormalization)
#
#  block1c_drop (FixedDropout  (None, 64, 64, 24)           0         ['block1c_project_bn[0][0]']
#  )
#
#  block1c_add (Add)           (None, 64, 64, 24)           0         ['block1c_drop[0][0]',
#                                                                      'block1b_add[0][0]']
#
#  block2a_expand_conv (Conv2  (None, 64, 64, 144)          3456      ['block1c_add[0][0]']
#  D)
#
#  block2a_expand_bn (BatchNo  (None, 64, 64, 144)          576       ['block2a_expand_conv[0][0]']
#  rmalization)
#
#  block2a_expand_activation   (None, 64, 64, 144)          0         ['block2a_expand_bn[0][0]']
#  (Activation)
#
#  block2a_dwconv (DepthwiseC  (None, 32, 32, 144)          1296      ['block2a_expand_activation[0]
#  onv2D)                                                             [0]']
#
#  block2a_bn (BatchNormaliza  (None, 32, 32, 144)          576       ['block2a_dwconv[0][0]']
#  tion)
#
#  block2a_activation (Activa  (None, 32, 32, 144)          0         ['block2a_bn[0][0]']
#  tion)
#
#  block2a_se_squeeze (Global  (None, 144)                  0         ['block2a_activation[0][0]']
#  AveragePooling2D)
#
#  block2a_se_reshape (Reshap  (None, 1, 1, 144)            0         ['block2a_se_squeeze[0][0]']
#  e)
#
#  block2a_se_reduce (Conv2D)  (None, 1, 1, 6)              870       ['block2a_se_reshape[0][0]']
#
#  block2a_se_expand (Conv2D)  (None, 1, 1, 144)            1008      ['block2a_se_reduce[0][0]']
#
#  block2a_se_excite (Multipl  (None, 32, 32, 144)          0         ['block2a_activation[0][0]',
#  y)                                                                  'block2a_se_expand[0][0]']
#
#  block2a_project_conv (Conv  (None, 32, 32, 40)           5760      ['block2a_se_excite[0][0]']
#  2D)
#
#  block2a_project_bn (BatchN  (None, 32, 32, 40)           160       ['block2a_project_conv[0][0]']
#  ormalization)
#
#  block2b_expand_conv (Conv2  (None, 32, 32, 240)          9600      ['block2a_project_bn[0][0]']
#  D)
#
#  block2b_expand_bn (BatchNo  (None, 32, 32, 240)          960       ['block2b_expand_conv[0][0]']
#  rmalization)
#
#  block2b_expand_activation   (None, 32, 32, 240)          0         ['block2b_expand_bn[0][0]']
#  (Activation)
#
#  block2b_dwconv (DepthwiseC  (None, 32, 32, 240)          2160      ['block2b_expand_activation[0]
#  onv2D)                                                             [0]']
#
#  block2b_bn (BatchNormaliza  (None, 32, 32, 240)          960       ['block2b_dwconv[0][0]']
#  tion)
#
#  block2b_activation (Activa  (None, 32, 32, 240)          0         ['block2b_bn[0][0]']
#  tion)
#
#  block2b_se_squeeze (Global  (None, 240)                  0         ['block2b_activation[0][0]']
#  AveragePooling2D)
#
#  block2b_se_reshape (Reshap  (None, 1, 1, 240)            0         ['block2b_se_squeeze[0][0]']
#  e)
#
#  block2b_se_reduce (Conv2D)  (None, 1, 1, 10)             2410      ['block2b_se_reshape[0][0]']
#
#  block2b_se_expand (Conv2D)  (None, 1, 1, 240)            2640      ['block2b_se_reduce[0][0]']
#
#  block2b_se_excite (Multipl  (None, 32, 32, 240)          0         ['block2b_activation[0][0]',
#  y)                                                                  'block2b_se_expand[0][0]']
#
#  block2b_project_conv (Conv  (None, 32, 32, 40)           9600      ['block2b_se_excite[0][0]']
#  2D)
#
#  block2b_project_bn (BatchN  (None, 32, 32, 40)           160       ['block2b_project_conv[0][0]']
#  ormalization)
#
#  block2b_drop (FixedDropout  (None, 32, 32, 40)           0         ['block2b_project_bn[0][0]']
#  )
#
#  block2b_add (Add)           (None, 32, 32, 40)           0         ['block2b_drop[0][0]',
#                                                                      'block2a_project_bn[0][0]']
#
#  block2c_expand_conv (Conv2  (None, 32, 32, 240)          9600      ['block2b_add[0][0]']
#  D)
#
#  block2c_expand_bn (BatchNo  (None, 32, 32, 240)          960       ['block2c_expand_conv[0][0]']
#  rmalization)
#
#  block2c_expand_activation   (None, 32, 32, 240)          0         ['block2c_expand_bn[0][0]']
#  (Activation)
#
#  block2c_dwconv (DepthwiseC  (None, 32, 32, 240)          2160      ['block2c_expand_activation[0]
#  onv2D)                                                             [0]']
#
#  block2c_bn (BatchNormaliza  (None, 32, 32, 240)          960       ['block2c_dwconv[0][0]']
#  tion)
#
#  block2c_activation (Activa  (None, 32, 32, 240)          0         ['block2c_bn[0][0]']
#  tion)
#
#  block2c_se_squeeze (Global  (None, 240)                  0         ['block2c_activation[0][0]']
#  AveragePooling2D)
#
#  block2c_se_reshape (Reshap  (None, 1, 1, 240)            0         ['block2c_se_squeeze[0][0]']
#  e)
#
#  block2c_se_reduce (Conv2D)  (None, 1, 1, 10)             2410      ['block2c_se_reshape[0][0]']
#
#  block2c_se_expand (Conv2D)  (None, 1, 1, 240)            2640      ['block2c_se_reduce[0][0]']
#
#  block2c_se_excite (Multipl  (None, 32, 32, 240)          0         ['block2c_activation[0][0]',
#  y)                                                                  'block2c_se_expand[0][0]']
#
#  block2c_project_conv (Conv  (None, 32, 32, 40)           9600      ['block2c_se_excite[0][0]']
#  2D)
#
#  block2c_project_bn (BatchN  (None, 32, 32, 40)           160       ['block2c_project_conv[0][0]']
#  ormalization)
#
#  block2c_drop (FixedDropout  (None, 32, 32, 40)           0         ['block2c_project_bn[0][0]']
#  )
#
#  block2c_add (Add)           (None, 32, 32, 40)           0         ['block2c_drop[0][0]',
#                                                                      'block2b_add[0][0]']
#
#  block2d_expand_conv (Conv2  (None, 32, 32, 240)          9600      ['block2c_add[0][0]']
#  D)
#
#  block2d_expand_bn (BatchNo  (None, 32, 32, 240)          960       ['block2d_expand_conv[0][0]']
#  rmalization)
#
#  block2d_expand_activation   (None, 32, 32, 240)          0         ['block2d_expand_bn[0][0]']
#  (Activation)
#
#  block2d_dwconv (DepthwiseC  (None, 32, 32, 240)          2160      ['block2d_expand_activation[0]
#  onv2D)                                                             [0]']
#
#  block2d_bn (BatchNormaliza  (None, 32, 32, 240)          960       ['block2d_dwconv[0][0]']
#  tion)
#
#  block2d_activation (Activa  (None, 32, 32, 240)          0         ['block2d_bn[0][0]']
#  tion)
#
#  block2d_se_squeeze (Global  (None, 240)                  0         ['block2d_activation[0][0]']
#  AveragePooling2D)
#
#  block2d_se_reshape (Reshap  (None, 1, 1, 240)            0         ['block2d_se_squeeze[0][0]']
#  e)
#
#  block2d_se_reduce (Conv2D)  (None, 1, 1, 10)             2410      ['block2d_se_reshape[0][0]']
#
#  block2d_se_expand (Conv2D)  (None, 1, 1, 240)            2640      ['block2d_se_reduce[0][0]']
#
#  block2d_se_excite (Multipl  (None, 32, 32, 240)          0         ['block2d_activation[0][0]',
#  y)                                                                  'block2d_se_expand[0][0]']
#
#  block2d_project_conv (Conv  (None, 32, 32, 40)           9600      ['block2d_se_excite[0][0]']
#  2D)
#
#  block2d_project_bn (BatchN  (None, 32, 32, 40)           160       ['block2d_project_conv[0][0]']
#  ormalization)
#
#  block2d_drop (FixedDropout  (None, 32, 32, 40)           0         ['block2d_project_bn[0][0]']
#  )
#
#  block2d_add (Add)           (None, 32, 32, 40)           0         ['block2d_drop[0][0]',
#                                                                      'block2c_add[0][0]']
#
#  block2e_expand_conv (Conv2  (None, 32, 32, 240)          9600      ['block2d_add[0][0]']
#  D)
#
#  block2e_expand_bn (BatchNo  (None, 32, 32, 240)          960       ['block2e_expand_conv[0][0]']
#  rmalization)
#
#  block2e_expand_activation   (None, 32, 32, 240)          0         ['block2e_expand_bn[0][0]']
#  (Activation)
#
#  block2e_dwconv (DepthwiseC  (None, 32, 32, 240)          2160      ['block2e_expand_activation[0]
#  onv2D)                                                             [0]']
#
#  block2e_bn (BatchNormaliza  (None, 32, 32, 240)          960       ['block2e_dwconv[0][0]']
#  tion)
#
#  block2e_activation (Activa  (None, 32, 32, 240)          0         ['block2e_bn[0][0]']
#  tion)
#
#  block2e_se_squeeze (Global  (None, 240)                  0         ['block2e_activation[0][0]']
#  AveragePooling2D)
#
#  block2e_se_reshape (Reshap  (None, 1, 1, 240)            0         ['block2e_se_squeeze[0][0]']
#  e)
#
#  block2e_se_reduce (Conv2D)  (None, 1, 1, 10)             2410      ['block2e_se_reshape[0][0]']
#
#  block2e_se_expand (Conv2D)  (None, 1, 1, 240)            2640      ['block2e_se_reduce[0][0]']
#
#  block2e_se_excite (Multipl  (None, 32, 32, 240)          0         ['block2e_activation[0][0]',
#  y)                                                                  'block2e_se_expand[0][0]']
#
#  block2e_project_conv (Conv  (None, 32, 32, 40)           9600      ['block2e_se_excite[0][0]']
#  2D)
#
#  block2e_project_bn (BatchN  (None, 32, 32, 40)           160       ['block2e_project_conv[0][0]']
#  ormalization)
#
#  block2e_drop (FixedDropout  (None, 32, 32, 40)           0         ['block2e_project_bn[0][0]']
#  )
#
#  block2e_add (Add)           (None, 32, 32, 40)           0         ['block2e_drop[0][0]',
#                                                                      'block2d_add[0][0]']
#
#  block3a_expand_conv (Conv2  (None, 32, 32, 240)          9600      ['block2e_add[0][0]']
#  D)
#
#  block3a_expand_bn (BatchNo  (None, 32, 32, 240)          960       ['block3a_expand_conv[0][0]']
#  rmalization)
#
#  block3a_expand_activation   (None, 32, 32, 240)          0         ['block3a_expand_bn[0][0]']
#  (Activation)
#
#  block3a_dwconv (DepthwiseC  (None, 16, 16, 240)          6000      ['block3a_expand_activation[0]
#  onv2D)                                                             [0]']
#
#  block3a_bn (BatchNormaliza  (None, 16, 16, 240)          960       ['block3a_dwconv[0][0]']
#  tion)
#
#  block3a_activation (Activa  (None, 16, 16, 240)          0         ['block3a_bn[0][0]']
#  tion)
#
#  block3a_se_squeeze (Global  (None, 240)                  0         ['block3a_activation[0][0]']
#  AveragePooling2D)
#
#  block3a_se_reshape (Reshap  (None, 1, 1, 240)            0         ['block3a_se_squeeze[0][0]']
#  e)
#
#  block3a_se_reduce (Conv2D)  (None, 1, 1, 10)             2410      ['block3a_se_reshape[0][0]']
#
#  block3a_se_expand (Conv2D)  (None, 1, 1, 240)            2640      ['block3a_se_reduce[0][0]']
#
#  block3a_se_excite (Multipl  (None, 16, 16, 240)          0         ['block3a_activation[0][0]',
#  y)                                                                  'block3a_se_expand[0][0]']
#
#  block3a_project_conv (Conv  (None, 16, 16, 64)           15360     ['block3a_se_excite[0][0]']
#  2D)
#
#  block3a_project_bn (BatchN  (None, 16, 16, 64)           256       ['block3a_project_conv[0][0]']
#  ormalization)
#
#  block3b_expand_conv (Conv2  (None, 16, 16, 384)          24576     ['block3a_project_bn[0][0]']
#  D)
#
#  block3b_expand_bn (BatchNo  (None, 16, 16, 384)          1536      ['block3b_expand_conv[0][0]']
#  rmalization)
#
#  block3b_expand_activation   (None, 16, 16, 384)          0         ['block3b_expand_bn[0][0]']
#  (Activation)
#
#  block3b_dwconv (DepthwiseC  (None, 16, 16, 384)          9600      ['block3b_expand_activation[0]
#  onv2D)                                                             [0]']
#
#  block3b_bn (BatchNormaliza  (None, 16, 16, 384)          1536      ['block3b_dwconv[0][0]']
#  tion)
#
#  block3b_activation (Activa  (None, 16, 16, 384)          0         ['block3b_bn[0][0]']
#  tion)
#
#  block3b_se_squeeze (Global  (None, 384)                  0         ['block3b_activation[0][0]']
#  AveragePooling2D)
#
#  block3b_se_reshape (Reshap  (None, 1, 1, 384)            0         ['block3b_se_squeeze[0][0]']
#  e)
#
#  block3b_se_reduce (Conv2D)  (None, 1, 1, 16)             6160      ['block3b_se_reshape[0][0]']
#
#  block3b_se_expand (Conv2D)  (None, 1, 1, 384)            6528      ['block3b_se_reduce[0][0]']
#
#  block3b_se_excite (Multipl  (None, 16, 16, 384)          0         ['block3b_activation[0][0]',
#  y)                                                                  'block3b_se_expand[0][0]']
#
#  block3b_project_conv (Conv  (None, 16, 16, 64)           24576     ['block3b_se_excite[0][0]']
#  2D)
#
#  block3b_project_bn (BatchN  (None, 16, 16, 64)           256       ['block3b_project_conv[0][0]']
#  ormalization)
#
#  block3b_drop (FixedDropout  (None, 16, 16, 64)           0         ['block3b_project_bn[0][0]']
#  )
#
#  block3b_add (Add)           (None, 16, 16, 64)           0         ['block3b_drop[0][0]',
#                                                                      'block3a_project_bn[0][0]']
#
#  block3c_expand_conv (Conv2  (None, 16, 16, 384)          24576     ['block3b_add[0][0]']
#  D)
#
#  block3c_expand_bn (BatchNo  (None, 16, 16, 384)          1536      ['block3c_expand_conv[0][0]']
#  rmalization)
#
#  block3c_expand_activation   (None, 16, 16, 384)          0         ['block3c_expand_bn[0][0]']
#  (Activation)
#
#  block3c_dwconv (DepthwiseC  (None, 16, 16, 384)          9600      ['block3c_expand_activation[0]
#  onv2D)                                                             [0]']
#
#  block3c_bn (BatchNormaliza  (None, 16, 16, 384)          1536      ['block3c_dwconv[0][0]']
#  tion)
#
#  block3c_activation (Activa  (None, 16, 16, 384)          0         ['block3c_bn[0][0]']
#  tion)
#
#  block3c_se_squeeze (Global  (None, 384)                  0         ['block3c_activation[0][0]']
#  AveragePooling2D)
#
#  block3c_se_reshape (Reshap  (None, 1, 1, 384)            0         ['block3c_se_squeeze[0][0]']
#  e)
#
#  block3c_se_reduce (Conv2D)  (None, 1, 1, 16)             6160      ['block3c_se_reshape[0][0]']
#
#  block3c_se_expand (Conv2D)  (None, 1, 1, 384)            6528      ['block3c_se_reduce[0][0]']
#
#  block3c_se_excite (Multipl  (None, 16, 16, 384)          0         ['block3c_activation[0][0]',
#  y)                                                                  'block3c_se_expand[0][0]']
#
#  block3c_project_conv (Conv  (None, 16, 16, 64)           24576     ['block3c_se_excite[0][0]']
#  2D)
#
#  block3c_project_bn (BatchN  (None, 16, 16, 64)           256       ['block3c_project_conv[0][0]']
#  ormalization)
#
#  block3c_drop (FixedDropout  (None, 16, 16, 64)           0         ['block3c_project_bn[0][0]']
#  )
#
#  block3c_add (Add)           (None, 16, 16, 64)           0         ['block3c_drop[0][0]',
#                                                                      'block3b_add[0][0]']
#
#  block3d_expand_conv (Conv2  (None, 16, 16, 384)          24576     ['block3c_add[0][0]']
#  D)
#
#  block3d_expand_bn (BatchNo  (None, 16, 16, 384)          1536      ['block3d_expand_conv[0][0]']
#  rmalization)
#
#  block3d_expand_activation   (None, 16, 16, 384)          0         ['block3d_expand_bn[0][0]']
#  (Activation)
#
#  block3d_dwconv (DepthwiseC  (None, 16, 16, 384)          9600      ['block3d_expand_activation[0]
#  onv2D)                                                             [0]']
#
#  block3d_bn (BatchNormaliza  (None, 16, 16, 384)          1536      ['block3d_dwconv[0][0]']
#  tion)
#
#  block3d_activation (Activa  (None, 16, 16, 384)          0         ['block3d_bn[0][0]']
#  tion)
#
#  block3d_se_squeeze (Global  (None, 384)                  0         ['block3d_activation[0][0]']
#  AveragePooling2D)
#
#  block3d_se_reshape (Reshap  (None, 1, 1, 384)            0         ['block3d_se_squeeze[0][0]']
#  e)
#
#  block3d_se_reduce (Conv2D)  (None, 1, 1, 16)             6160      ['block3d_se_reshape[0][0]']
#
#  block3d_se_expand (Conv2D)  (None, 1, 1, 384)            6528      ['block3d_se_reduce[0][0]']
#
#  block3d_se_excite (Multipl  (None, 16, 16, 384)          0         ['block3d_activation[0][0]',
#  y)                                                                  'block3d_se_expand[0][0]']
#
#  block3d_project_conv (Conv  (None, 16, 16, 64)           24576     ['block3d_se_excite[0][0]']
#  2D)
#
#  block3d_project_bn (BatchN  (None, 16, 16, 64)           256       ['block3d_project_conv[0][0]']
#  ormalization)
#
#  block3d_drop (FixedDropout  (None, 16, 16, 64)           0         ['block3d_project_bn[0][0]']
#  )
#
#  block3d_add (Add)           (None, 16, 16, 64)           0         ['block3d_drop[0][0]',
#                                                                      'block3c_add[0][0]']
#
# ...
#
#  block6i_se_reduce (Conv2D)  (None, 1, 1, 76)             138700    ['block6i_se_reshape[0][0]']
#
#  block6i_se_expand (Conv2D)  (None, 1, 1, 1824)           140448    ['block6i_se_reduce[0][0]']
#
#  block6i_se_excite (Multipl  (None, 4, 4, 1824)           0         ['block6i_activation[0][0]',
#  y)                                                                  'block6i_se_expand[0][0]']
#
#  block6i_project_conv (Conv  (None, 4, 4, 304)            554496    ['block6i_se_excite[0][0]']
#  2D)
#
#  block6i_project_bn (BatchN  (None, 4, 4, 304)            1216      ['block6i_project_conv[0][0]']
#  ormalization)
#
#  block6i_drop (FixedDropout  (None, 4, 4, 304)            0         ['block6i_project_bn[0][0]']
#  )
#
#  block6i_add (Add)           (None, 4, 4, 304)            0         ['block6i_drop[0][0]',
#                                                                      'block6h_add[0][0]']
#
#  block7a_expand_conv (Conv2  (None, 4, 4, 1824)           554496    ['block6i_add[0][0]']
#  D)
#
#  block7a_expand_bn (BatchNo  (None, 4, 4, 1824)           7296      ['block7a_expand_conv[0][0]']
#  rmalization)
#
#  block7a_expand_activation   (None, 4, 4, 1824)           0         ['block7a_expand_bn[0][0]']
#  (Activation)
#
#  block7a_dwconv (DepthwiseC  (None, 4, 4, 1824)           16416     ['block7a_expand_activation[0]
#  onv2D)                                                             [0]']
#
#  block7a_bn (BatchNormaliza  (None, 4, 4, 1824)           7296      ['block7a_dwconv[0][0]']
#  tion)
#
#  block7a_activation (Activa  (None, 4, 4, 1824)           0         ['block7a_bn[0][0]']
#  tion)
#
#  block7a_se_squeeze (Global  (None, 1824)                 0         ['block7a_activation[0][0]']
#  AveragePooling2D)
#
#  block7a_se_reshape (Reshap  (None, 1, 1, 1824)           0         ['block7a_se_squeeze[0][0]']
#  e)
#
#  block7a_se_reduce (Conv2D)  (None, 1, 1, 76)             138700    ['block7a_se_reshape[0][0]']
#
#  block7a_se_expand (Conv2D)  (None, 1, 1, 1824)           140448    ['block7a_se_reduce[0][0]']
#
#  block7a_se_excite (Multipl  (None, 4, 4, 1824)           0         ['block7a_activation[0][0]',
#  y)                                                                  'block7a_se_expand[0][0]']
#
#  block7a_project_conv (Conv  (None, 4, 4, 512)            933888    ['block7a_se_excite[0][0]']
#  2D)
#
#  block7a_project_bn (BatchN  (None, 4, 4, 512)            2048      ['block7a_project_conv[0][0]']
#  ormalization)
#
#  block7b_expand_conv (Conv2  (None, 4, 4, 3072)           1572864   ['block7a_project_bn[0][0]']
#  D)
#
#  block7b_expand_bn (BatchNo  (None, 4, 4, 3072)           12288     ['block7b_expand_conv[0][0]']
#  rmalization)
#
#  block7b_expand_activation   (None, 4, 4, 3072)           0         ['block7b_expand_bn[0][0]']
#  (Activation)
#
#  block7b_dwconv (DepthwiseC  (None, 4, 4, 3072)           27648     ['block7b_expand_activation[0]
#  onv2D)                                                             [0]']
#
#  block7b_bn (BatchNormaliza  (None, 4, 4, 3072)           12288     ['block7b_dwconv[0][0]']
#  tion)
#
#  block7b_activation (Activa  (None, 4, 4, 3072)           0         ['block7b_bn[0][0]']
#  tion)
#
#  block7b_se_squeeze (Global  (None, 3072)                 0         ['block7b_activation[0][0]']
#  AveragePooling2D)
#
#  block7b_se_reshape (Reshap  (None, 1, 1, 3072)           0         ['block7b_se_squeeze[0][0]']
#  e)
#
#  block7b_se_reduce (Conv2D)  (None, 1, 1, 128)            393344    ['block7b_se_reshape[0][0]']
#
#  block7b_se_expand (Conv2D)  (None, 1, 1, 3072)           396288    ['block7b_se_reduce[0][0]']
#
#  block7b_se_excite (Multipl  (None, 4, 4, 3072)           0         ['block7b_activation[0][0]',
#  y)                                                                  'block7b_se_expand[0][0]']
#
#  block7b_project_conv (Conv  (None, 4, 4, 512)            1572864   ['block7b_se_excite[0][0]']
#  2D)
#
#  block7b_project_bn (BatchN  (None, 4, 4, 512)            2048      ['block7b_project_conv[0][0]']
#  ormalization)
#
#  block7b_drop (FixedDropout  (None, 4, 4, 512)            0         ['block7b_project_bn[0][0]']
#  )
#
#  block7b_add (Add)           (None, 4, 4, 512)            0         ['block7b_drop[0][0]',
#                                                                      'block7a_project_bn[0][0]']
#
#  block7c_expand_conv (Conv2  (None, 4, 4, 3072)           1572864   ['block7b_add[0][0]']
#  D)
#
#  block7c_expand_bn (BatchNo  (None, 4, 4, 3072)           12288     ['block7c_expand_conv[0][0]']
#  rmalization)
#
#  block7c_expand_activation   (None, 4, 4, 3072)           0         ['block7c_expand_bn[0][0]']
#  (Activation)
#
#  block7c_dwconv (DepthwiseC  (None, 4, 4, 3072)           27648     ['block7c_expand_activation[0]
#  onv2D)                                                             [0]']
#
#  block7c_bn (BatchNormaliza  (None, 4, 4, 3072)           12288     ['block7c_dwconv[0][0]']
#  tion)
#
#  block7c_activation (Activa  (None, 4, 4, 3072)           0         ['block7c_bn[0][0]']
#  tion)
#
#  block7c_se_squeeze (Global  (None, 3072)                 0         ['block7c_activation[0][0]']
#  AveragePooling2D)
#
#  block7c_se_reshape (Reshap  (None, 1, 1, 3072)           0         ['block7c_se_squeeze[0][0]']
#  e)
#
#  block7c_se_reduce (Conv2D)  (None, 1, 1, 128)            393344    ['block7c_se_reshape[0][0]']
#
#  block7c_se_expand (Conv2D)  (None, 1, 1, 3072)           396288    ['block7c_se_reduce[0][0]']
#
#  block7c_se_excite (Multipl  (None, 4, 4, 3072)           0         ['block7c_activation[0][0]',
#  y)                                                                  'block7c_se_expand[0][0]']
#
#  block7c_project_conv (Conv  (None, 4, 4, 512)            1572864   ['block7c_se_excite[0][0]']
#  2D)
#
#  block7c_project_bn (BatchN  (None, 4, 4, 512)            2048      ['block7c_project_conv[0][0]']
#  ormalization)
#
#  block7c_drop (FixedDropout  (None, 4, 4, 512)            0         ['block7c_project_bn[0][0]']
#  )
#
#  block7c_add (Add)           (None, 4, 4, 512)            0         ['block7c_drop[0][0]',
#                                                                      'block7b_add[0][0]']
#
#  top_conv (Conv2D)           (None, 4, 4, 2048)           1048576   ['block7c_add[0][0]']
#
#  top_bn (BatchNormalization  (None, 4, 4, 2048)           8192      ['top_conv[0][0]']
#  )
#
#  top_activation (Activation  (None, 4, 4, 2048)           0         ['top_bn[0][0]']
#  )
#
#  head_pooling (GlobalAverag  (None, 2048)                 0         ['top_activation[0][0]']
#  ePooling2D)
#
#  head_dropout (Dropout)      (None, 2048)                 0         ['head_pooling[0][0]']
#
#  predict_Cat_Dog (Dense)     (None, 2)                    4098      ['head_dropout[0][0]']
#
# ==================================================================================================
# Total params: 28517618 (108.79 MB)
# Trainable params: 4098 (16.01 KB)
# Non-trainable params: 28513520 (108.77 MB)
# __________________________________________________________________________________________________

# %% [markdown]
# ## Callbacks
#
# - ReduceLROnPlateau : Reduce learning rate when a metric has stopped improving.

# %%
from tensorflow.keras.callbacks import ReduceLROnPlateau,EarlyStopping

learning_rate_reduction = ReduceLROnPlateau(monitor = 'val_accuracy',
                                              patience=2,
                                              factor=0.5,
                                              min_lr = 0.00001,
                                              verbose = 1)

# %% [markdown]
# ## Compile the model

# %%
from keras.optimizers import Adam

lr=1e-4
#Training
model.compile(loss='categorical_crossentropy',
              optimizer=optimizers.RMSprop(learning_rate=lr),
              metrics=['acc'])

# %% [markdown]
# ## Fit the model

# %%
num_epochs = 20
history_eff = model.fit(train_generator,
                        epochs = num_epochs,
                        validation_data = val_generator,
                        callbacks=learning_rate_reduction)
# Out:
# Epoch 1/20
# 250/250 [==============================] - ETA: 0s - loss: 0.5829 - acc: 0.6840
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,acc,val_loss,val_acc,lr
# 250/250 [==============================] - 168s 622ms/step - loss: 0.5829 - acc: 0.6840 - val_loss: 0.3895 - val_acc: 0.8600 - lr: 1.0000e-04
# Epoch 2/20
# 250/250 [==============================] - ETA: 0s - loss: 0.4198 - acc: 0.8130
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,acc,val_loss,val_acc,lr
# 250/250 [==============================] - 144s 575ms/step - loss: 0.4198 - acc: 0.8130 - val_loss: 0.2974 - val_acc: 0.8960 - lr: 1.0000e-04
# Epoch 3/20
# 250/250 [==============================] - ETA: 0s - loss: 0.3656 - acc: 0.8405
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,acc,val_loss,val_acc,lr
# 250/250 [==============================] - 151s 603ms/step - loss: 0.3656 - acc: 0.8405 - val_loss: 0.2614 - val_acc: 0.9200 - lr: 1.0000e-04
# Epoch 4/20
# 250/250 [==============================] - ETA: 0s - loss: 0.3590 - acc: 0.8465
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,acc,val_loss,val_acc,lr
# 250/250 [==============================] - 144s 574ms/step - loss: 0.3590 - acc: 0.8465 - val_loss: 0.2446 - val_acc: 0.9240 - lr: 1.0000e-04
# Epoch 5/20
# 250/250 [==============================] - ETA: 0s - loss: 0.3370 - acc: 0.8490
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,acc,val_loss,val_acc,lr
# 250/250 [==============================] - 144s 578ms/step - loss: 0.3370 - acc: 0.8490 - val_loss: 0.2298 - val_acc: 0.9280 - lr: 1.0000e-04
# Epoch 6/20
# 250/250 [==============================] - ETA: 0s - loss: 0.3316 - acc: 0.8545
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,acc,val_loss,val_acc,lr
# 250/250 [==============================] - 146s 582ms/step - loss: 0.3316 - acc: 0.8545 - val_loss: 0.2186 - val_acc: 0.9240 - lr: 1.0000e-04
# Epoch 7/20
# 250/250 [==============================] - ETA: 0s - loss: 0.3066 - acc: 0.8625
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,acc,val_loss,val_acc,lr
# 250/250 [==============================] - 150s 601ms/step - loss: 0.3066 - acc: 0.8625 - val_loss: 0.2119 - val_acc: 0.9200 - lr: 1.0000e-04
# Epoch 8/20
# 250/250 [==============================] - ETA: 0s - loss: 0.2972 - acc: 0.8710
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,acc,val_loss,val_acc,lr
# 250/250 [==============================] - 145s 582ms/step - loss: 0.2972 - acc: 0.8710 - val_loss: 0.2051 - val_acc: 0.9200 - lr: 1.0000e-04
# Epoch 9/20
# 250/250 [==============================] - ETA: 0s - loss: 0.2960 - acc: 0.8660
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,acc,val_loss,val_acc,lr
# 250/250 [==============================] - 144s 577ms/step - loss: 0.2960 - acc: 0.8660 - val_loss: 0.2010 - val_acc: 0.9200 - lr: 1.0000e-04
# Epoch 10/20
# 250/250 [==============================] - ETA: 0s - loss: 0.3083 - acc: 0.8650
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,acc,val_loss,val_acc,lr
# 250/250 [==============================] - 142s 569ms/step - loss: 0.3083 - acc: 0.8650 - val_loss: 0.1991 - val_acc: 0.9240 - lr: 1.0000e-04
# Epoch 11/20
# 250/250 [==============================] - ETA: 0s - loss: 0.2986 - acc: 0.8675
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,acc,val_loss,val_acc,lr
# 250/250 [==============================] - 142s 567ms/step - loss: 0.2986 - acc: 0.8675 - val_loss: 0.1974 - val_acc: 0.9240 - lr: 1.0000e-04
# Epoch 12/20
# 250/250 [==============================] - ETA: 0s - loss: 0.2933 - acc: 0.8770
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,acc,val_loss,val_acc,lr
# 250/250 [==============================] - 140s 562ms/step - loss: 0.2933 - acc: 0.8770 - val_loss: 0.1947 - val_acc: 0.9280 - lr: 1.0000e-04
# Epoch 13/20
# 250/250 [==============================] - ETA: 0s - loss: 0.2955 - acc: 0.8715
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,acc,val_loss,val_acc,lr
# 250/250 [==============================] - 142s 569ms/step - loss: 0.2955 - acc: 0.8715 - val_loss: 0.1926 - val_acc: 0.9280 - lr: 1.0000e-04
# Epoch 14/20
# 250/250 [==============================] - ETA: 0s - loss: 0.2833 - acc: 0.8830
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,acc,val_loss,val_acc,lr
# 250/250 [==============================] - 142s 567ms/step - loss: 0.2833 - acc: 0.8830 - val_loss: 0.1909 - val_acc: 0.9240 - lr: 1.0000e-04
# Epoch 15/20
# 250/250 [==============================] - ETA: 0s - loss: 0.2711 - acc: 0.8875
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,acc,val_loss,val_acc,lr
# 250/250 [==============================] - 141s 566ms/step - loss: 0.2711 - acc: 0.8875 - val_loss: 0.1905 - val_acc: 0.9320 - lr: 1.0000e-04
# Epoch 16/20
# 250/250 [==============================] - ETA: 0s - loss: 0.2946 - acc: 0.8685
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,acc,val_loss,val_acc,lr
# 250/250 [==============================] - 146s 585ms/step - loss: 0.2946 - acc: 0.8685 - val_loss: 0.1897 - val_acc: 0.9240 - lr: 1.0000e-04
# Epoch 17/20
# 250/250 [==============================] - ETA: 0s - loss: 0.2765 - acc: 0.8830
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,acc,val_loss,val_acc,lr
# 250/250 [==============================] - 145s 582ms/step - loss: 0.2765 - acc: 0.8830 - val_loss: 0.1883 - val_acc: 0.9200 - lr: 1.0000e-04
# Epoch 18/20
# 250/250 [==============================] - ETA: 0s - loss: 0.2810 - acc: 0.8765
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,acc,val_loss,val_acc,lr
# 250/250 [==============================] - 178s 713ms/step - loss: 0.2810 - acc: 0.8765 - val_loss: 0.1868 - val_acc: 0.9200 - lr: 1.0000e-04
# Epoch 19/20
# 250/250 [==============================] - ETA: 0s - loss: 0.2702 - acc: 0.8840
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,acc,val_loss,val_acc,lr
# 250/250 [==============================] - 145s 581ms/step - loss: 0.2702 - acc: 0.8840 - val_loss: 0.1869 - val_acc: 0.9240 - lr: 1.0000e-04
# Epoch 20/20
# 250/250 [==============================] - ETA: 0s - loss: 0.2666 - acc: 0.8870
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,acc,val_loss,val_acc,lr
# 250/250 [==============================] - 143s 573ms/step - loss: 0.2666 - acc: 0.8870 - val_loss: 0.1841 - val_acc: 0.9280 - lr: 1.0000e-04

# %%
## Set up model path
#Categorical Crossentropy
modelName  = "EffNetB5_CategoricalCrossentropy_Cat_Dog_Classes.h5"
Model2save = f"/content/drive/MyDrive/{modelName}"
model.save(Model2save)
### print
print(f"[INFO]: Save Model as: {Model2save}")
print(f"*"*100)
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# [INFO]: Save Model as: /content/drive/MyDrive/EffNetB5_CategoricalCrossentropy_Cat_Dog_Classes.h5
# ****************************************************************************************************

# %% [markdown]
# # Plot the results

# %%
train_acc = history_eff.history['acc']
train_loss = history_eff.history['loss']

val_acc = history_eff.history['val_acc']
val_loss = history_eff.history['val_loss']

index_loss = np.argmin(val_loss)
index_acc = np.argmax(val_acc)

val_lowest = val_loss[index_loss]
val_highest = val_acc[index_acc]

Epochs = [i+1 for i in range(len(train_acc))]

loss_label = f'Best Epoch = {str(index_loss + 1)}'
acc_label = f'Best Epoch = {str(index_acc + 1)}'

plt.figure(figsize= (20,8))
plt.style.use('fivethirtyeight')

plt.subplot(1,2,1)
plt.plot(Epochs , train_loss , 'r', label = 'Training Loss')
plt.plot(Epochs , val_loss , 'g' , label = 'Validation Loss')
plt.scatter(index_loss +1 , val_lowest , s = 150 , c = 'blue' , label = loss_label)
plt.title('Training vs Validation (loss)')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.subplot(1,2,2)
plt.plot(Epochs , train_acc , 'r', label= 'Training Accuracy')
plt.plot(Epochs , val_acc , 'g' , label = 'Validation Accuracy')
plt.scatter(index_acc + 1 , val_highest , s= 150 , c = 'blue' , label= acc_label)
plt.title('Training vs Validation (Accuracy)')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout
plt.show();

# %% [markdown]
# # Evaluation

# %%
# Evaluvate for train generator
loss,acc = model.evaluate(train_generator,batch_size = val_generator, verbose = 0)

print('The accuracy of the model for training data is:',acc*100)
print('The Loss of the model for training data is:',loss)

# Evaluvate for validation generator
loss,acc = model.evaluate(val_generator,batch_size = val_generator, verbose = 0)

print('The accuracy of the model for validation data is:',acc*100)
print('The Loss of the model for validation data is:',loss)
# Out:
# The accuracy of the model for training data is: 89.80000019073486
# The Loss of the model for training data is: 0.23101069033145905
# The accuracy of the model for validation data is: 92.79999732971191
# The Loss of the model for validation data is: 0.18409225344657898

# %% [markdown]
# # Prediction

# %%
import os
import numpy as np
import efficientnet.tfkeras
from tensorflow.keras.models import load_model
import tensorflow as tf
import pandas as pd

from tensorflow.keras.preprocessing import image
from tensorflow.keras.utils import get_file

# %% [markdown]
# ## Load model

# %%
model_dir = "/content/drive/MyDrive/EffNetB5_CategoricalCrossentropy_Cat_Dog_Classes.h5"
model_B5 = load_model(model_dir)
height = width = model_B5.input_shape[1]
print(height, width)
# Out:
# 128 128

# %%
model_B5.summary()
# Out:
# Model: "EffNet_Cat_Dog"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 128, 128, 3)]        0         []
#
#  stem_conv (Conv2D)          (None, 64, 64, 48)           1296      ['input_1[0][0]']
#
#  stem_bn (BatchNormalizatio  (None, 64, 64, 48)           192       ['stem_conv[0][0]']
#  n)
#
#  stem_activation (Activatio  (None, 64, 64, 48)           0         ['stem_bn[0][0]']
#  n)
#
#  block1a_dwconv (DepthwiseC  (None, 64, 64, 48)           432       ['stem_activation[0][0]']
#  onv2D)
#
#  block1a_bn (BatchNormaliza  (None, 64, 64, 48)           192       ['block1a_dwconv[0][0]']
#  tion)
#
#  block1a_activation (Activa  (None, 64, 64, 48)           0         ['block1a_bn[0][0]']
#  tion)
#
#  block1a_se_squeeze (Global  (None, 48)                   0         ['block1a_activation[0][0]']
#  AveragePooling2D)
#
#  block1a_se_reshape (Reshap  (None, 1, 1, 48)             0         ['block1a_se_squeeze[0][0]']
#  e)
#
#  block1a_se_reduce (Conv2D)  (None, 1, 1, 12)             588       ['block1a_se_reshape[0][0]']
#
#  block1a_se_expand (Conv2D)  (None, 1, 1, 48)             624       ['block1a_se_reduce[0][0]']
#
#  block1a_se_excite (Multipl  (None, 64, 64, 48)           0         ['block1a_activation[0][0]',
#  y)                                                                  'block1a_se_expand[0][0]']
#
#  block1a_project_conv (Conv  (None, 64, 64, 24)           1152      ['block1a_se_excite[0][0]']
#  2D)
#
#  block1a_project_bn (BatchN  (None, 64, 64, 24)           96        ['block1a_project_conv[0][0]']
#  ormalization)
#
#  block1b_dwconv (DepthwiseC  (None, 64, 64, 24)           216       ['block1a_project_bn[0][0]']
#  onv2D)
#
#  block1b_bn (BatchNormaliza  (None, 64, 64, 24)           96        ['block1b_dwconv[0][0]']
#  tion)
#
#  block1b_activation (Activa  (None, 64, 64, 24)           0         ['block1b_bn[0][0]']
#  tion)
#
#  block1b_se_squeeze (Global  (None, 24)                   0         ['block1b_activation[0][0]']
#  AveragePooling2D)
#
#  block1b_se_reshape (Reshap  (None, 1, 1, 24)             0         ['block1b_se_squeeze[0][0]']
#  e)
#
#  block1b_se_reduce (Conv2D)  (None, 1, 1, 6)              150       ['block1b_se_reshape[0][0]']
#
#  block1b_se_expand (Conv2D)  (None, 1, 1, 24)             168       ['block1b_se_reduce[0][0]']
#
#  block1b_se_excite (Multipl  (None, 64, 64, 24)           0         ['block1b_activation[0][0]',
#  y)                                                                  'block1b_se_expand[0][0]']
#
#  block1b_project_conv (Conv  (None, 64, 64, 24)           576       ['block1b_se_excite[0][0]']
#  2D)
#
#  block1b_project_bn (BatchN  (None, 64, 64, 24)           96        ['block1b_project_conv[0][0]']
#  ormalization)
#
#  block1b_drop (FixedDropout  (None, 64, 64, 24)           0         ['block1b_project_bn[0][0]']
#  )
#
#  block1b_add (Add)           (None, 64, 64, 24)           0         ['block1b_drop[0][0]',
#                                                                      'block1a_project_bn[0][0]']
#
#  block1c_dwconv (DepthwiseC  (None, 64, 64, 24)           216       ['block1b_add[0][0]']
#  onv2D)
#
#  block1c_bn (BatchNormaliza  (None, 64, 64, 24)           96        ['block1c_dwconv[0][0]']
#  tion)
#
#  block1c_activation (Activa  (None, 64, 64, 24)           0         ['block1c_bn[0][0]']
#  tion)
#
#  block1c_se_squeeze (Global  (None, 24)                   0         ['block1c_activation[0][0]']
#  AveragePooling2D)
#
#  block1c_se_reshape (Reshap  (None, 1, 1, 24)             0         ['block1c_se_squeeze[0][0]']
#  e)
#
#  block1c_se_reduce (Conv2D)  (None, 1, 1, 6)              150       ['block1c_se_reshape[0][0]']
#
#  block1c_se_expand (Conv2D)  (None, 1, 1, 24)             168       ['block1c_se_reduce[0][0]']
#
#  block1c_se_excite (Multipl  (None, 64, 64, 24)           0         ['block1c_activation[0][0]',
#  y)                                                                  'block1c_se_expand[0][0]']
#
#  block1c_project_conv (Conv  (None, 64, 64, 24)           576       ['block1c_se_excite[0][0]']
#  2D)
#
#  block1c_project_bn (BatchN  (None, 64, 64, 24)           96        ['block1c_project_conv[0][0]']
#  ormalization)
#
#  block1c_drop (FixedDropout  (None, 64, 64, 24)           0         ['block1c_project_bn[0][0]']
#  )
#
#  block1c_add (Add)           (None, 64, 64, 24)           0         ['block1c_drop[0][0]',
#                                                                      'block1b_add[0][0]']
#
#  block2a_expand_conv (Conv2  (None, 64, 64, 144)          3456      ['block1c_add[0][0]']
#  D)
#
#  block2a_expand_bn (BatchNo  (None, 64, 64, 144)          576       ['block2a_expand_conv[0][0]']
#  rmalization)
#
#  block2a_expand_activation   (None, 64, 64, 144)          0         ['block2a_expand_bn[0][0]']
#  (Activation)
#
#  block2a_dwconv (DepthwiseC  (None, 32, 32, 144)          1296      ['block2a_expand_activation[0]
#  onv2D)                                                             [0]']
#
#  block2a_bn (BatchNormaliza  (None, 32, 32, 144)          576       ['block2a_dwconv[0][0]']
#  tion)
#
#  block2a_activation (Activa  (None, 32, 32, 144)          0         ['block2a_bn[0][0]']
#  tion)
#
#  block2a_se_squeeze (Global  (None, 144)                  0         ['block2a_activation[0][0]']
#  AveragePooling2D)
#
#  block2a_se_reshape (Reshap  (None, 1, 1, 144)            0         ['block2a_se_squeeze[0][0]']
#  e)
#
#  block2a_se_reduce (Conv2D)  (None, 1, 1, 6)              870       ['block2a_se_reshape[0][0]']
#
#  block2a_se_expand (Conv2D)  (None, 1, 1, 144)            1008      ['block2a_se_reduce[0][0]']
#
#  block2a_se_excite (Multipl  (None, 32, 32, 144)          0         ['block2a_activation[0][0]',
#  y)                                                                  'block2a_se_expand[0][0]']
#
#  block2a_project_conv (Conv  (None, 32, 32, 40)           5760      ['block2a_se_excite[0][0]']
#  2D)
#
#  block2a_project_bn (BatchN  (None, 32, 32, 40)           160       ['block2a_project_conv[0][0]']
#  ormalization)
#
#  block2b_expand_conv (Conv2  (None, 32, 32, 240)          9600      ['block2a_project_bn[0][0]']
#  D)
#
#  block2b_expand_bn (BatchNo  (None, 32, 32, 240)          960       ['block2b_expand_conv[0][0]']
#  rmalization)
#
#  block2b_expand_activation   (None, 32, 32, 240)          0         ['block2b_expand_bn[0][0]']
#  (Activation)
#
#  block2b_dwconv (DepthwiseC  (None, 32, 32, 240)          2160      ['block2b_expand_activation[0]
#  onv2D)                                                             [0]']
#
#  block2b_bn (BatchNormaliza  (None, 32, 32, 240)          960       ['block2b_dwconv[0][0]']
#  tion)
#
#  block2b_activation (Activa  (None, 32, 32, 240)          0         ['block2b_bn[0][0]']
#  tion)
#
#  block2b_se_squeeze (Global  (None, 240)                  0         ['block2b_activation[0][0]']
#  AveragePooling2D)
#
#  block2b_se_reshape (Reshap  (None, 1, 1, 240)            0         ['block2b_se_squeeze[0][0]']
#  e)
#
#  block2b_se_reduce (Conv2D)  (None, 1, 1, 10)             2410      ['block2b_se_reshape[0][0]']
#
#  block2b_se_expand (Conv2D)  (None, 1, 1, 240)            2640      ['block2b_se_reduce[0][0]']
#
#  block2b_se_excite (Multipl  (None, 32, 32, 240)          0         ['block2b_activation[0][0]',
#  y)                                                                  'block2b_se_expand[0][0]']
#
#  block2b_project_conv (Conv  (None, 32, 32, 40)           9600      ['block2b_se_excite[0][0]']
#  2D)
#
#  block2b_project_bn (BatchN  (None, 32, 32, 40)           160       ['block2b_project_conv[0][0]']
#  ormalization)
#
#  block2b_drop (FixedDropout  (None, 32, 32, 40)           0         ['block2b_project_bn[0][0]']
#  )
#
#  block2b_add (Add)           (None, 32, 32, 40)           0         ['block2b_drop[0][0]',
#                                                                      'block2a_project_bn[0][0]']
#
#  block2c_expand_conv (Conv2  (None, 32, 32, 240)          9600      ['block2b_add[0][0]']
#  D)
#
#  block2c_expand_bn (BatchNo  (None, 32, 32, 240)          960       ['block2c_expand_conv[0][0]']
#  rmalization)
#
#  block2c_expand_activation   (None, 32, 32, 240)          0         ['block2c_expand_bn[0][0]']
#  (Activation)
#
#  block2c_dwconv (DepthwiseC  (None, 32, 32, 240)          2160      ['block2c_expand_activation[0]
#  onv2D)                                                             [0]']
#
#  block2c_bn (BatchNormaliza  (None, 32, 32, 240)          960       ['block2c_dwconv[0][0]']
#  tion)
#
#  block2c_activation (Activa  (None, 32, 32, 240)          0         ['block2c_bn[0][0]']
#  tion)
#
#  block2c_se_squeeze (Global  (None, 240)                  0         ['block2c_activation[0][0]']
#  AveragePooling2D)
#
#  block2c_se_reshape (Reshap  (None, 1, 1, 240)            0         ['block2c_se_squeeze[0][0]']
#  e)
#
#  block2c_se_reduce (Conv2D)  (None, 1, 1, 10)             2410      ['block2c_se_reshape[0][0]']
#
#  block2c_se_expand (Conv2D)  (None, 1, 1, 240)            2640      ['block2c_se_reduce[0][0]']
#
#  block2c_se_excite (Multipl  (None, 32, 32, 240)          0         ['block2c_activation[0][0]',
#  y)                                                                  'block2c_se_expand[0][0]']
#
#  block2c_project_conv (Conv  (None, 32, 32, 40)           9600      ['block2c_se_excite[0][0]']
#  2D)
#
#  block2c_project_bn (BatchN  (None, 32, 32, 40)           160       ['block2c_project_conv[0][0]']
#  ormalization)
#
#  block2c_drop (FixedDropout  (None, 32, 32, 40)           0         ['block2c_project_bn[0][0]']
#  )
#
#  block2c_add (Add)           (None, 32, 32, 40)           0         ['block2c_drop[0][0]',
#                                                                      'block2b_add[0][0]']
#
#  block2d_expand_conv (Conv2  (None, 32, 32, 240)          9600      ['block2c_add[0][0]']
#  D)
#
#  block2d_expand_bn (BatchNo  (None, 32, 32, 240)          960       ['block2d_expand_conv[0][0]']
#  rmalization)
#
#  block2d_expand_activation   (None, 32, 32, 240)          0         ['block2d_expand_bn[0][0]']
#  (Activation)
#
#  block2d_dwconv (DepthwiseC  (None, 32, 32, 240)          2160      ['block2d_expand_activation[0]
#  onv2D)                                                             [0]']
#
#  block2d_bn (BatchNormaliza  (None, 32, 32, 240)          960       ['block2d_dwconv[0][0]']
#  tion)
#
#  block2d_activation (Activa  (None, 32, 32, 240)          0         ['block2d_bn[0][0]']
#  tion)
#
#  block2d_se_squeeze (Global  (None, 240)                  0         ['block2d_activation[0][0]']
#  AveragePooling2D)
#
#  block2d_se_reshape (Reshap  (None, 1, 1, 240)            0         ['block2d_se_squeeze[0][0]']
#  e)
#
#  block2d_se_reduce (Conv2D)  (None, 1, 1, 10)             2410      ['block2d_se_reshape[0][0]']
#
#  block2d_se_expand (Conv2D)  (None, 1, 1, 240)            2640      ['block2d_se_reduce[0][0]']
#
#  block2d_se_excite (Multipl  (None, 32, 32, 240)          0         ['block2d_activation[0][0]',
#  y)                                                                  'block2d_se_expand[0][0]']
#
#  block2d_project_conv (Conv  (None, 32, 32, 40)           9600      ['block2d_se_excite[0][0]']
#  2D)
#
#  block2d_project_bn (BatchN  (None, 32, 32, 40)           160       ['block2d_project_conv[0][0]']
#  ormalization)
#
#  block2d_drop (FixedDropout  (None, 32, 32, 40)           0         ['block2d_project_bn[0][0]']
#  )
#
#  block2d_add (Add)           (None, 32, 32, 40)           0         ['block2d_drop[0][0]',
#                                                                      'block2c_add[0][0]']
#
#  block2e_expand_conv (Conv2  (None, 32, 32, 240)          9600      ['block2d_add[0][0]']
#  D)
#
#  block2e_expand_bn (BatchNo  (None, 32, 32, 240)          960       ['block2e_expand_conv[0][0]']
#  rmalization)
#
#  block2e_expand_activation   (None, 32, 32, 240)          0         ['block2e_expand_bn[0][0]']
#  (Activation)
#
#  block2e_dwconv (DepthwiseC  (None, 32, 32, 240)          2160      ['block2e_expand_activation[0]
#  onv2D)                                                             [0]']
#
#  block2e_bn (BatchNormaliza  (None, 32, 32, 240)          960       ['block2e_dwconv[0][0]']
#  tion)
#
#  block2e_activation (Activa  (None, 32, 32, 240)          0         ['block2e_bn[0][0]']
#  tion)
#
#  block2e_se_squeeze (Global  (None, 240)                  0         ['block2e_activation[0][0]']
#  AveragePooling2D)
#
#  block2e_se_reshape (Reshap  (None, 1, 1, 240)            0         ['block2e_se_squeeze[0][0]']
#  e)
#
#  block2e_se_reduce (Conv2D)  (None, 1, 1, 10)             2410      ['block2e_se_reshape[0][0]']
#
#  block2e_se_expand (Conv2D)  (None, 1, 1, 240)            2640      ['block2e_se_reduce[0][0]']
#
#  block2e_se_excite (Multipl  (None, 32, 32, 240)          0         ['block2e_activation[0][0]',
#  y)                                                                  'block2e_se_expand[0][0]']
#
#  block2e_project_conv (Conv  (None, 32, 32, 40)           9600      ['block2e_se_excite[0][0]']
#  2D)
#
#  block2e_project_bn (BatchN  (None, 32, 32, 40)           160       ['block2e_project_conv[0][0]']
#  ormalization)
#
#  block2e_drop (FixedDropout  (None, 32, 32, 40)           0         ['block2e_project_bn[0][0]']
#  )
#
#  block2e_add (Add)           (None, 32, 32, 40)           0         ['block2e_drop[0][0]',
#                                                                      'block2d_add[0][0]']
#
#  block3a_expand_conv (Conv2  (None, 32, 32, 240)          9600      ['block2e_add[0][0]']
#  D)
#
#  block3a_expand_bn (BatchNo  (None, 32, 32, 240)          960       ['block3a_expand_conv[0][0]']
#  rmalization)
#
#  block3a_expand_activation   (None, 32, 32, 240)          0         ['block3a_expand_bn[0][0]']
#  (Activation)
#
#  block3a_dwconv (DepthwiseC  (None, 16, 16, 240)          6000      ['block3a_expand_activation[0]
#  onv2D)                                                             [0]']
#
#  block3a_bn (BatchNormaliza  (None, 16, 16, 240)          960       ['block3a_dwconv[0][0]']
#  tion)
#
#  block3a_activation (Activa  (None, 16, 16, 240)          0         ['block3a_bn[0][0]']
#  tion)
#
#  block3a_se_squeeze (Global  (None, 240)                  0         ['block3a_activation[0][0]']
#  AveragePooling2D)
#
#  block3a_se_reshape (Reshap  (None, 1, 1, 240)            0         ['block3a_se_squeeze[0][0]']
#  e)
#
#  block3a_se_reduce (Conv2D)  (None, 1, 1, 10)             2410      ['block3a_se_reshape[0][0]']
#
#  block3a_se_expand (Conv2D)  (None, 1, 1, 240)            2640      ['block3a_se_reduce[0][0]']
#
#  block3a_se_excite (Multipl  (None, 16, 16, 240)          0         ['block3a_activation[0][0]',
#  y)                                                                  'block3a_se_expand[0][0]']
#
#  block3a_project_conv (Conv  (None, 16, 16, 64)           15360     ['block3a_se_excite[0][0]']
#  2D)
#
#  block3a_project_bn (BatchN  (None, 16, 16, 64)           256       ['block3a_project_conv[0][0]']
#  ormalization)
#
#  block3b_expand_conv (Conv2  (None, 16, 16, 384)          24576     ['block3a_project_bn[0][0]']
#  D)
#
#  block3b_expand_bn (BatchNo  (None, 16, 16, 384)          1536      ['block3b_expand_conv[0][0]']
#  rmalization)
#
#  block3b_expand_activation   (None, 16, 16, 384)          0         ['block3b_expand_bn[0][0]']
#  (Activation)
#
#  block3b_dwconv (DepthwiseC  (None, 16, 16, 384)          9600      ['block3b_expand_activation[0]
#  onv2D)                                                             [0]']
#
#  block3b_bn (BatchNormaliza  (None, 16, 16, 384)          1536      ['block3b_dwconv[0][0]']
#  tion)
#
#  block3b_activation (Activa  (None, 16, 16, 384)          0         ['block3b_bn[0][0]']
#  tion)
#
#  block3b_se_squeeze (Global  (None, 384)                  0         ['block3b_activation[0][0]']
#  AveragePooling2D)
#
#  block3b_se_reshape (Reshap  (None, 1, 1, 384)            0         ['block3b_se_squeeze[0][0]']
#  e)
#
#  block3b_se_reduce (Conv2D)  (None, 1, 1, 16)             6160      ['block3b_se_reshape[0][0]']
#
#  block3b_se_expand (Conv2D)  (None, 1, 1, 384)            6528      ['block3b_se_reduce[0][0]']
#
#  block3b_se_excite (Multipl  (None, 16, 16, 384)          0         ['block3b_activation[0][0]',
#  y)                                                                  'block3b_se_expand[0][0]']
#
#  block3b_project_conv (Conv  (None, 16, 16, 64)           24576     ['block3b_se_excite[0][0]']
#  2D)
#
#  block3b_project_bn (BatchN  (None, 16, 16, 64)           256       ['block3b_project_conv[0][0]']
#  ormalization)
#
#  block3b_drop (FixedDropout  (None, 16, 16, 64)           0         ['block3b_project_bn[0][0]']
#  )
#
#  block3b_add (Add)           (None, 16, 16, 64)           0         ['block3b_drop[0][0]',
#                                                                      'block3a_project_bn[0][0]']
#
#  block3c_expand_conv (Conv2  (None, 16, 16, 384)          24576     ['block3b_add[0][0]']
#  D)
#
#  block3c_expand_bn (BatchNo  (None, 16, 16, 384)          1536      ['block3c_expand_conv[0][0]']
#  rmalization)
#
#  block3c_expand_activation   (None, 16, 16, 384)          0         ['block3c_expand_bn[0][0]']
#  (Activation)
#
#  block3c_dwconv (DepthwiseC  (None, 16, 16, 384)          9600      ['block3c_expand_activation[0]
#  onv2D)                                                             [0]']
#
#  block3c_bn (BatchNormaliza  (None, 16, 16, 384)          1536      ['block3c_dwconv[0][0]']
#  tion)
#
#  block3c_activation (Activa  (None, 16, 16, 384)          0         ['block3c_bn[0][0]']
#  tion)
#
#  block3c_se_squeeze (Global  (None, 384)                  0         ['block3c_activation[0][0]']
#  AveragePooling2D)
#
#  block3c_se_reshape (Reshap  (None, 1, 1, 384)            0         ['block3c_se_squeeze[0][0]']
#  e)
#
#  block3c_se_reduce (Conv2D)  (None, 1, 1, 16)             6160      ['block3c_se_reshape[0][0]']
#
#  block3c_se_expand (Conv2D)  (None, 1, 1, 384)            6528      ['block3c_se_reduce[0][0]']
#
#  block3c_se_excite (Multipl  (None, 16, 16, 384)          0         ['block3c_activation[0][0]',
#  y)                                                                  'block3c_se_expand[0][0]']
#
#  block3c_project_conv (Conv  (None, 16, 16, 64)           24576     ['block3c_se_excite[0][0]']
#  2D)
#
#  block3c_project_bn (BatchN  (None, 16, 16, 64)           256       ['block3c_project_conv[0][0]']
#  ormalization)
#
#  block3c_drop (FixedDropout  (None, 16, 16, 64)           0         ['block3c_project_bn[0][0]']
#  )
#
#  block3c_add (Add)           (None, 16, 16, 64)           0         ['block3c_drop[0][0]',
#                                                                      'block3b_add[0][0]']
#
#  block3d_expand_conv (Conv2  (None, 16, 16, 384)          24576     ['block3c_add[0][0]']
#  D)
#
#  block3d_expand_bn (BatchNo  (None, 16, 16, 384)          1536      ['block3d_expand_conv[0][0]']
#  rmalization)
#
#  block3d_expand_activation   (None, 16, 16, 384)          0         ['block3d_expand_bn[0][0]']
#  (Activation)
#
#  block3d_dwconv (DepthwiseC  (None, 16, 16, 384)          9600      ['block3d_expand_activation[0]
#  onv2D)                                                             [0]']
#
#  block3d_bn (BatchNormaliza  (None, 16, 16, 384)          1536      ['block3d_dwconv[0][0]']
#  tion)
#
#  block3d_activation (Activa  (None, 16, 16, 384)          0         ['block3d_bn[0][0]']
#  tion)
#
#  block3d_se_squeeze (Global  (None, 384)                  0         ['block3d_activation[0][0]']
#  AveragePooling2D)
#
#  block3d_se_reshape (Reshap  (None, 1, 1, 384)            0         ['block3d_se_squeeze[0][0]']
#  e)
#
#  block3d_se_reduce (Conv2D)  (None, 1, 1, 16)             6160      ['block3d_se_reshape[0][0]']
#
#  block3d_se_expand (Conv2D)  (None, 1, 1, 384)            6528      ['block3d_se_reduce[0][0]']
#
#  block3d_se_excite (Multipl  (None, 16, 16, 384)          0         ['block3d_activation[0][0]',
#  y)                                                                  'block3d_se_expand[0][0]']
#
#  block3d_project_conv (Conv  (None, 16, 16, 64)           24576     ['block3d_se_excite[0][0]']
#  2D)
#
#  block3d_project_bn (BatchN  (None, 16, 16, 64)           256       ['block3d_project_conv[0][0]']
#  ormalization)
#
#  block3d_drop (FixedDropout  (None, 16, 16, 64)           0         ['block3d_project_bn[0][0]']
#  )
#
#  block3d_add (Add)           (None, 16, 16, 64)           0         ['block3d_drop[0][0]',
#                                                                      'block3c_add[0][0]']
#
# ...
#
#  block6i_se_reduce (Conv2D)  (None, 1, 1, 76)             138700    ['block6i_se_reshape[0][0]']
#
#  block6i_se_expand (Conv2D)  (None, 1, 1, 1824)           140448    ['block6i_se_reduce[0][0]']
#
#  block6i_se_excite (Multipl  (None, 4, 4, 1824)           0         ['block6i_activation[0][0]',
#  y)                                                                  'block6i_se_expand[0][0]']
#
#  block6i_project_conv (Conv  (None, 4, 4, 304)            554496    ['block6i_se_excite[0][0]']
#  2D)
#
#  block6i_project_bn (BatchN  (None, 4, 4, 304)            1216      ['block6i_project_conv[0][0]']
#  ormalization)
#
#  block6i_drop (FixedDropout  (None, 4, 4, 304)            0         ['block6i_project_bn[0][0]']
#  )
#
#  block6i_add (Add)           (None, 4, 4, 304)            0         ['block6i_drop[0][0]',
#                                                                      'block6h_add[0][0]']
#
#  block7a_expand_conv (Conv2  (None, 4, 4, 1824)           554496    ['block6i_add[0][0]']
#  D)
#
#  block7a_expand_bn (BatchNo  (None, 4, 4, 1824)           7296      ['block7a_expand_conv[0][0]']
#  rmalization)
#
#  block7a_expand_activation   (None, 4, 4, 1824)           0         ['block7a_expand_bn[0][0]']
#  (Activation)
#
#  block7a_dwconv (DepthwiseC  (None, 4, 4, 1824)           16416     ['block7a_expand_activation[0]
#  onv2D)                                                             [0]']
#
#  block7a_bn (BatchNormaliza  (None, 4, 4, 1824)           7296      ['block7a_dwconv[0][0]']
#  tion)
#
#  block7a_activation (Activa  (None, 4, 4, 1824)           0         ['block7a_bn[0][0]']
#  tion)
#
#  block7a_se_squeeze (Global  (None, 1824)                 0         ['block7a_activation[0][0]']
#  AveragePooling2D)
#
#  block7a_se_reshape (Reshap  (None, 1, 1, 1824)           0         ['block7a_se_squeeze[0][0]']
#  e)
#
#  block7a_se_reduce (Conv2D)  (None, 1, 1, 76)             138700    ['block7a_se_reshape[0][0]']
#
#  block7a_se_expand (Conv2D)  (None, 1, 1, 1824)           140448    ['block7a_se_reduce[0][0]']
#
#  block7a_se_excite (Multipl  (None, 4, 4, 1824)           0         ['block7a_activation[0][0]',
#  y)                                                                  'block7a_se_expand[0][0]']
#
#  block7a_project_conv (Conv  (None, 4, 4, 512)            933888    ['block7a_se_excite[0][0]']
#  2D)
#
#  block7a_project_bn (BatchN  (None, 4, 4, 512)            2048      ['block7a_project_conv[0][0]']
#  ormalization)
#
#  block7b_expand_conv (Conv2  (None, 4, 4, 3072)           1572864   ['block7a_project_bn[0][0]']
#  D)
#
#  block7b_expand_bn (BatchNo  (None, 4, 4, 3072)           12288     ['block7b_expand_conv[0][0]']
#  rmalization)
#
#  block7b_expand_activation   (None, 4, 4, 3072)           0         ['block7b_expand_bn[0][0]']
#  (Activation)
#
#  block7b_dwconv (DepthwiseC  (None, 4, 4, 3072)           27648     ['block7b_expand_activation[0]
#  onv2D)                                                             [0]']
#
#  block7b_bn (BatchNormaliza  (None, 4, 4, 3072)           12288     ['block7b_dwconv[0][0]']
#  tion)
#
#  block7b_activation (Activa  (None, 4, 4, 3072)           0         ['block7b_bn[0][0]']
#  tion)
#
#  block7b_se_squeeze (Global  (None, 3072)                 0         ['block7b_activation[0][0]']
#  AveragePooling2D)
#
#  block7b_se_reshape (Reshap  (None, 1, 1, 3072)           0         ['block7b_se_squeeze[0][0]']
#  e)
#
#  block7b_se_reduce (Conv2D)  (None, 1, 1, 128)            393344    ['block7b_se_reshape[0][0]']
#
#  block7b_se_expand (Conv2D)  (None, 1, 1, 3072)           396288    ['block7b_se_reduce[0][0]']
#
#  block7b_se_excite (Multipl  (None, 4, 4, 3072)           0         ['block7b_activation[0][0]',
#  y)                                                                  'block7b_se_expand[0][0]']
#
#  block7b_project_conv (Conv  (None, 4, 4, 512)            1572864   ['block7b_se_excite[0][0]']
#  2D)
#
#  block7b_project_bn (BatchN  (None, 4, 4, 512)            2048      ['block7b_project_conv[0][0]']
#  ormalization)
#
#  block7b_drop (FixedDropout  (None, 4, 4, 512)            0         ['block7b_project_bn[0][0]']
#  )
#
#  block7b_add (Add)           (None, 4, 4, 512)            0         ['block7b_drop[0][0]',
#                                                                      'block7a_project_bn[0][0]']
#
#  block7c_expand_conv (Conv2  (None, 4, 4, 3072)           1572864   ['block7b_add[0][0]']
#  D)
#
#  block7c_expand_bn (BatchNo  (None, 4, 4, 3072)           12288     ['block7c_expand_conv[0][0]']
#  rmalization)
#
#  block7c_expand_activation   (None, 4, 4, 3072)           0         ['block7c_expand_bn[0][0]']
#  (Activation)
#
#  block7c_dwconv (DepthwiseC  (None, 4, 4, 3072)           27648     ['block7c_expand_activation[0]
#  onv2D)                                                             [0]']
#
#  block7c_bn (BatchNormaliza  (None, 4, 4, 3072)           12288     ['block7c_dwconv[0][0]']
#  tion)
#
#  block7c_activation (Activa  (None, 4, 4, 3072)           0         ['block7c_bn[0][0]']
#  tion)
#
#  block7c_se_squeeze (Global  (None, 3072)                 0         ['block7c_activation[0][0]']
#  AveragePooling2D)
#
#  block7c_se_reshape (Reshap  (None, 1, 1, 3072)           0         ['block7c_se_squeeze[0][0]']
#  e)
#
#  block7c_se_reduce (Conv2D)  (None, 1, 1, 128)            393344    ['block7c_se_reshape[0][0]']
#
#  block7c_se_expand (Conv2D)  (None, 1, 1, 3072)           396288    ['block7c_se_reduce[0][0]']
#
#  block7c_se_excite (Multipl  (None, 4, 4, 3072)           0         ['block7c_activation[0][0]',
#  y)                                                                  'block7c_se_expand[0][0]']
#
#  block7c_project_conv (Conv  (None, 4, 4, 512)            1572864   ['block7c_se_excite[0][0]']
#  2D)
#
#  block7c_project_bn (BatchN  (None, 4, 4, 512)            2048      ['block7c_project_conv[0][0]']
#  ormalization)
#
#  block7c_drop (FixedDropout  (None, 4, 4, 512)            0         ['block7c_project_bn[0][0]']
#  )
#
#  block7c_add (Add)           (None, 4, 4, 512)            0         ['block7c_drop[0][0]',
#                                                                      'block7b_add[0][0]']
#
#  top_conv (Conv2D)           (None, 4, 4, 2048)           1048576   ['block7c_add[0][0]']
#
#  top_bn (BatchNormalization  (None, 4, 4, 2048)           8192      ['top_conv[0][0]']
#  )
#
#  top_activation (Activation  (None, 4, 4, 2048)           0         ['top_bn[0][0]']
#  )
#
#  head_pooling (GlobalAverag  (None, 2048)                 0         ['top_activation[0][0]']
#  ePooling2D)
#
#  head_dropout (Dropout)      (None, 2048)                 0         ['head_pooling[0][0]']
#
#  predict_Cat_Dog (Dense)     (None, 2)                    4098      ['head_dropout[0][0]']
#
# ==================================================================================================
# Total params: 28517618 (108.79 MB)
# Trainable params: 4098 (16.01 KB)
# Non-trainable params: 28513520 (108.77 MB)
# __________________________________________________________________________________________________

# %%
# label_dict = {0: 'Cat', 1: 'Dog'}
# print(label_dict)

label_dict = dict((v,k) for k,v in labels.items())
print(label_dict)
# Out:
# {0: 'Cat', 1: 'Dog'}

# %%
def process_image(img_path):
    # Read the image and resize it
    img = image.load_img(img_path, target_size=(height, width))
    # Convert it to a Numpy array with target shape.
    x = image.img_to_array(img)
    # Reshape
    x = x.reshape((1,) + x.shape)
    x /= 255.

    return x

# %%
def predict(img_path, model_B5):
    img_x = process_image(img_path)
    predict = model_B5.predict([img_x])
    predict0 = predict[0]
    result = np.argmax(predict0)
    pred_label = label_dict[result]
    pred_prob = predict0[result]

    print(f"[INFO]: Predict Classes ==> {pred_label} With Probability {pred_prob*100:.4f}%")

# %% [markdown]
# # Exercise
#
# ทดลองนำภาพ นก รถยนต์ เสือ สิงโต และ สุนัขจิ้งจอก มาทำการทำนายและรายงานผลการทำนายแต่ละภาพ

# %%
img_path1 = "/content/drive/MyDrive/PMUB_PersonalAI/BitNet/Exercise/bird.jpeg"
predict(img_path1, model_B5)
image.load_img(img_path1, target_size=(height, width))
# Out:
# 1/1 [==============================] - 0s 101ms/step
# [INFO]: Predict Classes ==> Dog With Probability 72.4468%
# <PIL.Image.Image image mode=RGB size=128x128>

# %%
img_path2 = "/content/drive/MyDrive/PMUB_PersonalAI/BitNet/Exercise/car.png"
predict(img_path2, model_B5)
image.load_img(img_path2, target_size=(height, width))
# Out:
# 1/1 [==============================] - 0s 99ms/step
# [INFO]: Predict Classes ==> Dog With Probability 90.1783%
# /usr/local/lib/python3.10/dist-packages/PIL/Image.py:1054: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# <PIL.Image.Image image mode=RGB size=128x128>

# %%
img_path3 = "/content/drive/MyDrive/PMUB_PersonalAI/BitNet/Exercise/tiger.jpg"
predict(img_path3, model_B5)
image.load_img(img_path3, target_size=(height, width))
# Out:
# 1/1 [==============================] - 0s 104ms/step
# [INFO]: Predict Classes ==> Dog With Probability 77.9063%
# <PIL.Image.Image image mode=RGB size=128x128>

# %%
img_path4 = "/content/drive/MyDrive/PMUB_PersonalAI/BitNet/Exercise/lion.jpg"
predict(img_path4, model_B5)
image.load_img(img_path4, target_size=(height, width))
# Out:
# 1/1 [==============================] - 0s 92ms/step
# [INFO]: Predict Classes ==> Dog With Probability 87.9042%
# <PIL.Image.Image image mode=RGB size=128x128>

# %%
img_path5 = "/content/drive/MyDrive/PMUB_PersonalAI/BitNet/Exercise/fox.jpg"
predict(img_path5, model_B5)
image.load_img(img_path5, target_size=(height, width))
# Out:
# 1/1 [==============================] - 0s 111ms/step
# [INFO]: Predict Classes ==> Dog With Probability 97.0470%
# <PIL.Image.Image image mode=RGB size=128x128>

# %% [markdown]
# # Exercise
#
# Print output ของ network

# %%
predict
# Out:
# array([0.33885816, 0.6611418 ], dtype=float32)

# %% [markdown]
# --------------------------------------------------------------------------------------

# %% [markdown]
# ## Evaluating Model Performance
#
# - Confusion matrix

# %%
print(X_test.shape)
X_test.head()
# Out:
# (250, 2)
#                                           filename label
# 1095   /content/sample_data/PetImages/Cat/6355.jpg   Cat
# 1179  /content/sample_data/PetImages/Cat/10091.jpg   Cat
# 925    /content/sample_data/PetImages/Dog/2207.jpg   Dog
# 1019  /content/sample_data/PetImages/Dog/12386.jpg   Dog
# 556    /content/sample_data/PetImages/Cat/3595.jpg   Cat

# %%
# label_dict = {0: 'Cat', 1: 'Dog'}
# print(label_dict)

label_dict = dict((v,k) for k,v in labels.items())
print(label_dict)
# Out:
# {0: 'Cat', 1: 'Dog'}

# %%
from tensorflow.keras.preprocessing import image

def predict_image(img_path):
    # Read the image and resize it
    img = image.load_img(img_path, target_size=(height, width))
    # Convert it to a Numpy array with target shape.
    x = image.img_to_array(img)
    # Reshape
    x = x.reshape((1,) + x.shape)
    x /= 255.
    result = model.predict([x])

    return result[0]

# %%
#Predict
pred_list = list()
prob_list = list()
img_path=X_test['filename'].tolist()
for i in range(0,len(img_path)):
    predict = predict_image(img_path[i])
    result = np.argmax(predict)
    pred_list.append(label_dict[result])
    prob_list.append(predict[result])
# Out:
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 88ms/step
# 1/1 [==============================] - 0s 99ms/step
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 103ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 99ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 109ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 99ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 106ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 104ms/step
# 1/1 [==============================] - 0s 99ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 105ms/step
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 125ms/step
# 1/1 [==============================] - 0s 144ms/step
# 1/1 [==============================] - 0s 137ms/step
# 1/1 [==============================] - 0s 139ms/step
# 1/1 [==============================] - 0s 137ms/step
# 1/1 [==============================] - 0s 140ms/step
# 1/1 [==============================] - 0s 155ms/step
# 1/1 [==============================] - 0s 138ms/step
# 1/1 [==============================] - 0s 153ms/step
# 1/1 [==============================] - 0s 137ms/step
# 1/1 [==============================] - 0s 136ms/step
# 1/1 [==============================] - 0s 141ms/step
# 1/1 [==============================] - 0s 162ms/step
# 1/1 [==============================] - 0s 156ms/step
# 1/1 [==============================] - 0s 144ms/step
# 1/1 [==============================] - 0s 145ms/step
# 1/1 [==============================] - 0s 149ms/step
# 1/1 [==============================] - 0s 171ms/step
# 1/1 [==============================] - 0s 144ms/step
# 1/1 [==============================] - 0s 135ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 106ms/step
# 1/1 [==============================] - 0s 125ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 109ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 113ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 88ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 112ms/step
# 1/1 [==============================] - 0s 88ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 89ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 89ms/step
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 89ms/step
# 1/1 [==============================] - 0s 89ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 87ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 107ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 112ms/step
# 1/1 [==============================] - 0s 135ms/step
# 1/1 [==============================] - 0s 155ms/step
# 1/1 [==============================] - 0s 142ms/step
# 1/1 [==============================] - 0s 142ms/step
# 1/1 [==============================] - 0s 134ms/step
# 1/1 [==============================] - 0s 138ms/step
# 1/1 [==============================] - 0s 150ms/step
# 1/1 [==============================] - 0s 138ms/step
# 1/1 [==============================] - 0s 135ms/step
# 1/1 [==============================] - 0s 142ms/step
# 1/1 [==============================] - 0s 141ms/step
# 1/1 [==============================] - 0s 146ms/step
# 1/1 [==============================] - 0s 157ms/step
# 1/1 [==============================] - 0s 150ms/step
# 1/1 [==============================] - 0s 181ms/step
# 1/1 [==============================] - 0s 165ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 106ms/step
# 1/1 [==============================] - 0s 89ms/step
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 106ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 110ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 99ms/step
# 1/1 [==============================] - 0s 99ms/step
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 88ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 88ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 107ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 105ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 99ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 89ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 88ms/step
# 1/1 [==============================] - 0s 89ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 105ms/step
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 142ms/step
# 1/1 [==============================] - 0s 149ms/step
# 1/1 [==============================] - 0s 138ms/step
# 1/1 [==============================] - 0s 152ms/step
# 1/1 [==============================] - 0s 147ms/step
# 1/1 [==============================] - 0s 159ms/step
# 1/1 [==============================] - 0s 148ms/step
# 1/1 [==============================] - 0s 145ms/step
# 1/1 [==============================] - 0s 141ms/step
# 1/1 [==============================] - 0s 145ms/step
# 1/1 [==============================] - 0s 137ms/step
# 1/1 [==============================] - 0s 137ms/step
# 1/1 [==============================] - 0s 147ms/step
# 1/1 [==============================] - 0s 144ms/step
# 1/1 [==============================] - 0s 140ms/step
# 1/1 [==============================] - 0s 164ms/step
# 1/1 [==============================] - 0s 142ms/step
# 1/1 [==============================] - 0s 129ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 103ms/step
# 1/1 [==============================] - 0s 89ms/step
# 1/1 [==============================] - 0s 97ms/step

# %%
predict
# Out:
# array([0.33885816, 0.6611418 ], dtype=float32)

# %%
print(len(pred_list))
print(len(prob_list))

X_test['category'] = pred_list
X_test['Prob'] = prob_list
X_test.head()
# Out:
# 250
# 250
#                                           filename label category      Prob
# 1095   /content/sample_data/PetImages/Cat/6355.jpg   Cat      Cat  0.997411
# 1179  /content/sample_data/PetImages/Cat/10091.jpg   Cat      Cat  0.998892
# 925    /content/sample_data/PetImages/Dog/2207.jpg   Dog      Dog  0.987233
# 1019  /content/sample_data/PetImages/Dog/12386.jpg   Dog      Cat  0.754911
# 556    /content/sample_data/PetImages/Cat/3595.jpg   Cat      Cat  0.997594

# %%
import numpy as np
from sklearn.metrics import confusion_matrix

act = X_test['label'].array
pred = X_test['category'].array

cmat = confusion_matrix(act, pred)
print('classifier accuracy = {}%'.format((100.*np.trace(cmat))/(np.sum(cmat))))

#Marking the Confusion Matrix
from sklearn.metrics import classification_report,confusion_matrix
print(classification_report(act, pred))#performance
# Out:
# classifier accuracy = 93.6%
#               precision    recall  f1-score   support
#
#          Cat       0.95      0.92      0.93       125
#          Dog       0.92      0.95      0.94       125
#
#     accuracy                           0.94       250
#    macro avg       0.94      0.94      0.94       250
# weighted avg       0.94      0.94      0.94       250

# %% [markdown]
# ## Confusion matrix

# %%
#create CF
data = {'Actual': act,'Predicted' : pred,}
df = pd.DataFrame(data, columns=['Actual','Predicted'])
conf_mat = pd.crosstab(df['Actual'],df['Predicted'],rownames=['Actual'],colnames=['Predicted'])

#Confusion matrix
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
cm = confusion_matrix(act, pred)

#plot Confusion matrix
import seaborn as sns
sns.set()
fig, ax = plt.subplots(figsize=(8, 5))

ax = sns.heatmap(conf_mat, annot=True, fmt="d", cmap="YlGnBu") #Blues,Oranges,Reds
ax.set_title('Confusion matrix',fontsize=20)
ax.set_ylabel('True label',fontsize=18)
ax.set_xlabel('Predicted label',fontsize=18)
# Out:
# Text(0.5, 1.2499999999999805, 'Predicted label')

# %% [markdown]
# ---------------------------------------

# %%
img_path=X_test['filename'].tolist()
img_x  = predict_image(img_path[0])
img_x
# Out:
# 1/1 [==============================] - 0s 93ms/step
# array([0.9974106 , 0.00258941], dtype=float32)

# %%
image.load_img(img_path[0], target_size=(height, width))
# Out:
# <PIL.Image.Image image mode=RGB size=128x128>
